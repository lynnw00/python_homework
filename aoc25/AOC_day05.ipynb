# %%
from util import file_to_list

# %%
test = file_to_list("C:/Users/Lynnw/Python/AOC/data_test_day05.txt")

# %%
test
# Out:
# ['3-5', '10-14', '16-20', '12-18', '', '1', '5', '8', '11', '17', '32']

# %% [markdown]
# Checking overlaps
#
# Function with range and ingredient, return true or false.

# %%
6 in range(4, 12) #do not use
# Out:
# True
