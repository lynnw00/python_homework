# %%
s = "..."

# %%
count_A = s.count('A')
count_C = s.count('C')
count_G = s.count('G')
count_T = s.count('T')

# %%
print(count_A, count_C, count_G, count_T)
# Out:
# 199 202 219 192

# %%
nucleotide_count = { 
    'A': s.count('A'),
    'C': s.count('C'),
    'G': s.count('G'),
    'T': s.count('T')
    }
print('Nucleotides:', nucleotide_count)
# Out:
# Nucleotides: {'A': 199, 'C': 202, 'G': 219, 'T': 192}
