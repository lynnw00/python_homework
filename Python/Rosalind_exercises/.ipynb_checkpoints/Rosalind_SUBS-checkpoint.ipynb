# %%
s = "..."
t = "ATCCTACAT"

location = []
for i in range(len(s) - len(t) + 1):
    if s[i : i + len(t)] == t:
        location.append(i + 1)
print(*location)
# Out:
# 11 18 34 58 195 202 223 277 284 313 361 368 401 408 431 464 566 573 580 668 689 721 728 753 760
