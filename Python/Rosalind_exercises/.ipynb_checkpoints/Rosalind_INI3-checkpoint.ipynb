# %%
s = "HumptyDumptysatonawallHumptyDumptyhadagreatfallAlltheKingshorsesandalltheKingsmenCouldntputHumptyDumptyinhisplaceagain."

# %%
part1 = s[22:28]
part2 = s[97:103]
print(part1, part2)
# Out:
# Humpty Dumpty

# %%
s = "0aUV9ZW9xkhcrgdrbyaGOtWvFjHxS0gGQVWrqGQ3xHceb6H8rk8QqRSAE8BVrrahuYAnodontaRdmMiKLpjxLaqvVYklST0JhExVxtm7AyCrv9bKaklbghCcpzOF2YsIn2bFMY6Bnn3zlLtfNgiI7OSZJshMSbM35Ou0cLavgZZpicaodiCiz."

# %%
part1 = s[66:74]
part2 = s[171:175]
print(part1, part2)
# Out:
# Anodonta pica
