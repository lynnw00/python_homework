# %%
DNA = "..."

comp = '' 
for nucleotide in DNA:
    if nucleotide == 'A':
        comp += 'T'
    elif nucleotide == 'T':
        comp += 'A'
    elif nucleotide == 'G':
        comp += 'C'  
    elif nucleotide == 'C':
        comp += 'G'
print(comp)
# Out:
# ...

# %%
rev_comp = ''

for letter in comp:
    rev_comp = letter + rev_comp

print(rev_comp)
# Out:
# ...
